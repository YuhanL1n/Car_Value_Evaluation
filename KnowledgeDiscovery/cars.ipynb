# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv('cars.csv')
cars = cars.loc[cars['year'].isin(range(1988, 2019))]
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191289 entries, 0 to 213925
# Data columns (total 14 columns):
# make and model    191278 non-null object
# year              191289 non-null int64
# VIN               191249 non-null object
# condition         191289 non-null object
# cylinders         191289 non-null object
# drive             191289 non-null object
# fuel              191289 non-null object
# color             191289 non-null object
# odometer          191289 non-null object
# size              191289 non-null object
# title             191289 non-null object
# transmission      191289 non-null object
# type              191289 non-null object
# price             191289 non-null int64
# dtypes: int64(2), object(12)
# memory usage: 21.9+ MB

# %%
plt.hist(cars['year'], bins=30)
plt.title('Histogram of Cars Made from 1988 to 2018 (N ~ 190K)')
plt.xlabel('Year')
plt.ylabel('Number of Cars Post on Craigslist')
plt.show()

# %%
price_groupby_year = cars['price'].groupby(cars['year'])
price_groupby_year.describe()
# Out:
#         count           mean           std  min      25%      50%       75%  \
# year
# 1988   1299.0   15358.726713  2.844165e+05  1.0   1200.0   2500.0   5000.00
# 1989   1539.0   16611.702404  2.974767e+05  1.0   1400.0   2800.0   5000.00
# 1990   1412.0    6751.312323  5.515446e+04  1.0   1200.0   2500.0   5000.00
# 1991   1589.0    6627.191945  5.352078e+04  1.0   1200.0   2500.0   4500.00
# 1992   1691.0   79865.920757  3.003208e+06  1.0   1200.0   2300.0   4200.00
# 1993   2170.0    8507.218894  2.162475e+05  1.0   1100.0   2000.0   3900.00
# 1994   2928.0   14882.029030  3.206545e+05  1.0   1000.0   2000.0   3900.00
# 1995   3924.0    4337.070082  3.357211e+04  1.0   1000.0   2000.0   4000.00
# 1996   3790.0    6463.752770  1.479861e+05  1.0   1000.0   2000.0   3800.00
# 1997   5129.0    5638.134529  1.412131e+05  1.0   1200.0   2000.0   3800.00
# 1998   5949.0    3416.681795  2.183263e+04  1.0   1200.0   2000.0   3500.00
# 1999   7550.0    5527.807417  1.184344e+05  1.0   1200.0   2200.0   3900.00
# 2000   8795.0    6518.389426  1.648850e+05  1.0   1300.0   2300.0   3800.00
# 2001   9876.0    4947.728838  1.020691e+05  1.0   1500.0   2500.0   4250.00
# 2002  10920.0    9027.110348  4.792445e+05  1.0   1550.0   2650.0   4300.00
# 2003  12908.0    6853.986752  1.540809e+05  1.0   1800.0   3000.0   4800.00
# 2004  13737.0  170735.288709  1.835266e+07  1.0   2000.0   3500.0   5850.00
# 2005  14020.0    9062.501284  2.456774e+05  1.0   2350.0   3900.0   6250.00
# 2006  13938.0    6012.489238  6.413478e+03  1.0   2800.0   4500.0   6998.00
# 2007  13764.0    7201.295190  1.645128e+04  1.0   3300.0   5200.0   8500.00
# 2008  11932.0    8301.329702  4.759823e+04  1.0   3650.0   5900.0   9900.00
# 2009   6811.0   10024.965057  1.118858e+05  1.0   3999.0   6000.0   9800.00
# 2010   6190.0   10302.577383  3.930661e+04  1.0   4900.0   7500.0  11968.75
# 2011   5957.0   12799.894578  1.997311e+04  1.0   6500.0   9600.0  16554.00
# 2012   5846.0   12852.794560  1.176455e+04  1.0   6500.0   9800.0  16508.00
# 2013   4806.0   17176.593841  1.447381e+05  1.0   8000.0  12000.0  19500.00
# 2014   4573.0   20452.273781  1.400623e+05  1.0   9500.0  14528.0  24500.00
# 2015   3618.0   20531.241294  1.538607e+04  1.0  11000.0  17000.0  27998.50
# 2016   2594.0   27670.447186  1.147777e+05  1.0  12825.0  20000.0  31500.00
# 2017   1527.0   29288.277669  2.604102e+05  1.0    700.0  16900.0  33900.00
# 2018    507.0   29902.802761  2.717043e+05  1.0     30.0    275.0   1500.00
#
#                max
# year
# 1988  9.999999e+06
# 1989  9.999999e+06
# 1990  1.234568e+06
# 1991  1.111111e+06
# 1992  1.234568e+08
# 1993  9.999999e+06
# 1994  9.999999e+06
# 1995  1.235789e+06
# 1996  8.888888e+06
# 1997  9.999999e+06
# 1998  1.222222e+06
# 1999  9.999999e+06
# 2000  9.000000e+06
# 2001  9.999999e+06
# 2002  5.000600e+07
# 2003  9.999999e+06
# 2004  2.147484e+09
# 2005  2.000280e+07
# 2006  2.250000e+05
# 2007  1.234567e+06
# 2008  5.002000e+06
# 2009  8.970000e+06
# 2010  2.402000e+06
# 2011  1.000000e+06
# 2012  4.444440e+05
# 2013  9.999999e+06
# 2014  9.000000e+06
# 2015  3.330000e+05
# 2016  3.502018e+06
# 2017  9.999999e+06
# 2018  5.004000e+06

# %%
year = []
price = []
count = []
for name, group in price_groupby_year:
    q1, q3 = group.quantile([0.25, 0.75])
    iqr = q3 - q1
    group = group[(group > q1 - iqr * 1.5) & (group < q3 + iqr * 1.5)]
    year.append(name)
    price.append(group.mean())
    count.append(group.size)
plt.scatter(year, price)
plt.xlabel('Year')
plt.ylabel('Price')
plt.grid()    
plt.show()

# %%
plt.bar(year, count)
plt.title('Distribution of Cars Made from 1988 to 2018 (N~180K)')
plt.xlabel('Year')
plt.ylabel('Number of Cars Posted on Craigslist')
plt.show()

# %%
cars.loc[(cars['year'] == 2018) & (cars['price'] < 1000)]
# Out:
#                   make and model  year       VIN  condition     cylinders  \
# 362                     michelin  2018      None        new          None
# 844               Show polishing  2018      None       None          None
# 845               Show polishing  2018      None       None          None
# 1055                  ford f-250  2018      None       None          None
# 1626             Monster Drumset  2018      None       None          None
# 3047               Headache rack  2018      None  excellent          None
# 4879        Gmc Chevrolet 10 lug  2018      None       good  12 cylinders
# 4935                        xxxx  2018      None       None          None
# 5493                         any  2018      None       None          None
# 5704                        2018  2018  00000000       None          None
# 6171                      Taotao  2018      None       None          None
# 8196                      ONLINE  2018      None       None          None
# 9139                         any  2018      None       None          None
# 9477                  all models  2018      None       None          None
# 9647                         any  2018      None       None          None
# 9964                  all models  2018      None       None          None
# 11198                  Bully Dog  2018      None       None          None
# 11522                    Hoosier  2018      None       None          None
# 13128                       Ford  2018      None       None          None
# 14375                    barnett  2018      None       None          None
# 14782                        any  2018      None       None          None
# 16424                        Any  2018      None       None          None
# 17837                    Mad dog  2018      None       None          None
# 18153             anvil trailers  2018      None        new         other
# 21089                  Good year  2018      None       None          None
# 21146          Tires/Rubber Mats  2018      None       None          None
# 21586                  chop shop  2018      None    salvage          None
# 21645                        any  2018      None    salvage         other
# 21981   chevrolet 1500 silverado  2018      None       None          None
# 22085                  all kinds  2018      None    salvage  12 cylinders
# ...                          ...   ...       ...        ...           ...
# 185393                      Ford  2018      None        new          None
# 186938                       S10  2018      None       None          None
# 187276                  American  2018      None       None          None
# 187747                       S10  2018      None       None          None
# 188182                   Vw audi  2018      None       None          None
# 189259                       Any  2018      None       None          None
# 189938                    Dodbab  2018      None       None          None
# 191217              22 inch rims  2018      None   like new          None
# 191991             jeep wrangler  2018      None       None          None
# 192985                         S  2018      None       None          None
# 193574          chevrolet camaro  2018      None       None          None
# 194823                  JL AUDIO  2018      None       None          None
# 194824                  JL AUDIO  2018      None       None          None
# 194827                    Cleary  2018      None       None          None
# 196162                    Gutter  2018      None       None          None
# 196400                       Idk  2018      None       None          None
# 196690                       any  2018      None       None          None
# 197057              Champiro Ice  2018      None       None          None
# 197193                    Dunlap  2018      None       None          None
# 197432       jeep grand cherokee  2018      None       None          None
# 197446                    Dunlap  2018      None       None          None
# 198318                  Champiro  2018      None       None          None
# 200605                       any  2018      None       None          None
# 202756                  American  2018      None       None          None
# 202854              chevy blazer  2018      None       None          None
# 203567                      Ford  2018      None       None          None
# 208376                  American  2018      None       None          None
# 209963                       all  2018      None       None          None
# 210617               ford escape  2018      None       None          None
# 213573                       all  2018      None       None          None
#
#        drive      fuel   color odometer       size       title transmission  \
# 362     None     other    None     None       None       clean        other
# 844     None     other    None     None       None       clean        other
# 845     None     other    None     None       None       clean        other
# 1055    None       gas    None     None       None       clean    automatic
# 1626    None     other    None     None       None       clean        other
# 3047    None     other   black     None       None     missing        other
# 4879     rwd     other  custom     None  full-size       clean        other
# 4935    None     other    None     None       None       clean        other
# 5493    None       gas    None     None       None       clean        other
# 5704    None       gas    None     None       None       clean        other
# 6171    None       gas    None     None       None       clean    automatic
# 8196    None     other    None     None       None       clean        other
# 9139    None       gas    None     None       None       clean        other
# 9477    None     other    None     None       None       clean        other
# 9647    None       gas    None     None       None       clean        other
# 9964    None     other    None     None       None       clean        other
# 11198   None    diesel    None     None       None       clean        other
# 11522   None       gas    None     None       None       clean    automatic
# 13128   None    diesel    None     None       None     missing       manual
# 14375   None     other    None     None       None       clean        other
# 14782   None       gas    None     None       None       clean        other
# 16424   None     other    None     None       None       clean        other
# 17837   None       gas    None     None       None       clean    automatic
# 18153    rwd     other  custom     None       None       clean        other
# 21089   None       gas    None     None       None       clean       manual
# 21146   None     other    None     None       None       clean        other
# 21586   None       gas    None     None       None     rebuilt    automatic
# 21645    4wd     other  custom     None  full-size     missing        other
# 21981   None       gas    None     None       None       clean        other
# 22085    4wd     other  custom     None       None     missing        other
# ...      ...       ...     ...      ...        ...         ...          ...
# 185393  None       gas    None     None       None       clean        other
# 186938  None     other    None     None       None     missing        other
# 187276  None  electric    None     None       None       clean        other
# 187747  None     other    None     None       None     missing        other
# 188182  None       gas    None     None       None       clean        other
# 189259  None     other    None     None       None       clean        other
# 189938  None  electric    None     None       None     missing        other
# 191217  None     other    None     None       None       clean        other
# 191991  None     other    None     None       None  parts only        other
# 192985  None     other    None     None       None       clean        other
# 193574  None       gas    None     None       None       clean    automatic
# 194823  None     other    None     None       None       clean        other
# 194824  None     other    None     None       None       clean        other
# 194827  None     other    None     None       None       clean    automatic
# 196162  None     other    None     None       None       clean        other
# 196400  None     other    None     None       None       clean       manual
# 196690  None       gas    None     None       None       clean    automatic
# 197057  None       gas    None     None       None       clean       manual
# 197193  None       gas    None     None       None       clean       manual
# 197432  None       gas    None     None       None       clean    automatic
# 197446  None       gas    None     None       None       clean       manual
# 198318  None       gas    None        0       None       clean    automatic
# 200605  None       gas    None     None       None       clean    automatic
# 202756  None  electric    None     None       None       clean        other
# 202854  None       gas    None     None       None       clean    automatic
# 203567  None    diesel    None     None       None       clean       manual
# 208376  None  electric    None     None       None       clean        other
# 209963  None     other    None     None       None       clean        other
# 210617  None       gas    None     None       None       clean    automatic
# 213573  None     other    None     None       None       clean        other
#
#                type  price
# 362            None      1
# 844            None      1
# 845            None      1
# 1055           None     90
# 1626           None      1
# 3047         pickup    275
# 4879          truck    100
# 4935           None      5
# 5493           None      1
# 5704           None     55
# 6171           None    599
# 8196           None     89
# 9139           None      1
# 9477           None      1
# 9647           None      1
# 9964           None      1
# 11198          None    200
# 11522          None    300
# 13128          None     45
# 14375          None    150
# 14782          None      1
# 16424          None     20
# 17837          None     30
# 18153          None     20
# 21089          None     40
# 21146          None      1
# 21586          None      1
# 21645          None      1
# 21981          None    800
# 22085        pickup    100
# ...             ...    ...
# 185393         None      2
# 186938         None     20
# 187276         None    123
# 187747         None     40
# 188182         None    450
# 189259         None    800
# 189938         None    200
# 191217         None    900
# 191991         None    575
# 192985         None    900
# 193574         None      1
# 194823         None     45
# 194824         None     45
# 194827         None     20
# 196162         None      1
# 196400         None    150
# 196690         None    300
# 197057         None    300
# 197193         None    200
# 197432         None      1
# 197446         None    200
# 198318         None    300
# 200605         None     60
# 202756         None    123
# 202854         None      1
# 203567         None    875
# 208376         None    123
# 209963         None      1
# 210617  convertible     50
# 213573         None      1
#
# [324 rows x 14 columns]
